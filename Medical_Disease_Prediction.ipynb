# %%
# Import Libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset
df = pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\DATA SCIENCE\project\medical_disease_prediction_10000.csv")
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
# First 5 Rows
df.head()
# Out:
#    Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0   23    Male  17.5            102           177          161         88
# 1   69    Male  31.1            118           256          147         92
# 2   61  Female  31.3            114           206          193         74
# 3   47  Female  23.9            105           162          253         68
# 4   47    Male  28.3            148           121          280         84
#
#   Smoking Alcohol PhysicalActivity FamilyHistory       Disease
# 0      No      No           Medium            No       Healthy
# 1      No      No             High           Yes  Pre-Diabetes
# 2     Yes      No           Medium            No       Healthy
# 3      No      No              Low            No       Healthy
# 4      No     Yes             High            No       Healthy

# %%
# First 10 Rows
df.head(10)
# Out:
#    Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0   23    Male  17.5            102           177          161         88
# 1   69    Male  31.1            118           256          147         92
# 2   61  Female  31.3            114           206          193         74
# 3   47  Female  23.9            105           162          253         68
# 4   47    Male  28.3            148           121          280         84
# 5   75  Female  25.0             90           136          126         59
# 6   23  Female  27.1            125            85          212         71
# 7   64    Male  20.8            101           102          308         88
# 8   31  Female  28.8            145           177          285        107
# 9   24    Male  18.6            158            76          308         88
#
#   Smoking Alcohol PhysicalActivity FamilyHistory       Disease
# 0      No      No           Medium            No       Healthy
# ...

# %%
# Last 5 Rows
df.tail()
# Out:
#       Age Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 9995   49   Male  27.1            177           183          268         59
# 9996   84   Male  29.2            142           215          145         77
# 9997   41   Male  22.8            177           265          133         71
# 9998   55   Male  29.0            126           241          298         57
# 9999   59   Male  32.2            151           162          225         93
#
#      Smoking Alcohol PhysicalActivity FamilyHistory       Disease
# 9995      No      No             High            No  Hypertension
# 9996      No     Yes             High           Yes  Hypertension
# 9997      No      No           Medium           Yes  Hypertension
# 9998      No      No           Medium           Yes  Pre-Diabetes
# 9999      No      No             High           Yes  Pre-Diabetes

# %%
# Last 10 Rows
df.tail(10)
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 9990   39  Female  24.2            149           181          284         66
# 9991   32    Male  25.7            172           175          307        101
# 9992   79    Male  32.2             99           256          247         84
# 9993   29    Male  22.1             95           150          144         58
# 9994   82  Female  21.7            153           273          139         61
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
#      Smoking Alcohol PhysicalActivity FamilyHistory       Disease
# ...

# %%
# Dataset Information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               10000 non-null  int64
#  1   Gender            10000 non-null  str
#  2   BMI               10000 non-null  float64
#  3   BloodPressure     10000 non-null  int64
#  4   GlucoseLevel      10000 non-null  int64
#  5   Cholesterol       10000 non-null  int64
#  6   HeartRate         10000 non-null  int64
#  7   Smoking           10000 non-null  str
#  8   Alcohol           10000 non-null  str
#  9   PhysicalActivity  10000 non-null  str
#  10  FamilyHistory     10000 non-null  str
#  11  Disease           10000 non-null  str
# dtypes: float64(1), int64(5), str(6)
# memory usage: 937.6 KB

# %%
# Shape of Dataset
df.shape
# Out:
# (10000, 12)

# %%
# Column Names
df.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'BloodPressure', 'GlucoseLevel', 'Cholesterol',
#        'HeartRate', 'Smoking', 'Alcohol', 'PhysicalActivity', 'FamilyHistory',
#        'Disease'],
#       dtype='str')

# %%
# Access Individual Columns
df[['Age']]
# Out:
#       Age
# 0      23
# 1      69
# 2      61
# 3      47
# 4      47
# ...   ...
# 9995   49
# 9996   84
# 9997   41
# 9998   55
# 9999   59
#
# [10000 rows x 1 columns]

# %%
df[['Gender']]
# Out:
#       Gender
# 0       Male
# 1       Male
# 2     Female
# 3     Female
# 4       Male
# ...      ...
# 9995    Male
# 9996    Male
# 9997    Male
# 9998    Male
# 9999    Male
#
# [10000 rows x 1 columns]

# %%
df[['BMI']]
# Out:
#        BMI
# 0     17.5
# 1     31.1
# 2     31.3
# 3     23.9
# 4     28.3
# ...    ...
# 9995  27.1
# 9996  29.2
# 9997  22.8
# 9998  29.0
# 9999  32.2
#
# [10000 rows x 1 columns]

# %%
df[['BloodPressure']]
# Out:
#       BloodPressure
# 0               102
# 1               118
# 2               114
# 3               105
# 4               148
# ...             ...
# 9995            177
# 9996            142
# 9997            177
# 9998            126
# 9999            151
#
# [10000 rows x 1 columns]

# %%
df[['GlucoseLevel']]
# Out:
#       GlucoseLevel
# 0              177
# 1              256
# 2              206
# 3              162
# 4              121
# ...            ...
# 9995           183
# 9996           215
# 9997           265
# 9998           241
# 9999           162
#
# [10000 rows x 1 columns]

# %%
df[['Cholesterol']]
# Out:
#       Cholesterol
# 0             161
# 1             147
# 2             193
# 3             253
# 4             280
# ...           ...
# 9995          268
# 9996          145
# 9997          133
# 9998          298
# 9999          225
#
# [10000 rows x 1 columns]

# %%
df[['HeartRate']]
# Out:
#       HeartRate
# 0            88
# 1            92
# 2            74
# 3            68
# 4            84
# ...         ...
# 9995         59
# 9996         77
# 9997         71
# 9998         57
# 9999         93
#
# [10000 rows x 1 columns]

# %%
df[['Smoking']]
# Out:
#      Smoking
# 0         No
# 1         No
# 2        Yes
# 3         No
# 4         No
# ...      ...
# 9995      No
# 9996      No
# 9997      No
# 9998      No
# 9999      No
#
# [10000 rows x 1 columns]

# %%
df[['Alcohol']]
# Out:
#      Alcohol
# 0         No
# 1         No
# 2         No
# 3         No
# 4        Yes
# ...      ...
# 9995      No
# 9996     Yes
# 9997      No
# 9998      No
# 9999      No
#
# [10000 rows x 1 columns]

# %%
df[['PhysicalActivity']]
# Out:
#      PhysicalActivity
# 0              Medium
# 1                High
# 2              Medium
# 3                 Low
# 4                High
# ...               ...
# 9995             High
# 9996             High
# 9997           Medium
# 9998           Medium
# 9999             High
#
# [10000 rows x 1 columns]

# %%
df[['FamilyHistory']]
# Out:
#      FamilyHistory
# 0               No
# 1              Yes
# 2               No
# 3               No
# 4               No
# ...            ...
# 9995            No
# 9996           Yes
# 9997           Yes
# 9998           Yes
# 9999           Yes
#
# [10000 rows x 1 columns]

# %%
df[['Disease']]
# Out:
#            Disease
# 0          Healthy
# 1     Pre-Diabetes
# 2          Healthy
# 3          Healthy
# 4          Healthy
# ...            ...
# 9995  Hypertension
# 9996  Hypertension
# 9997  Hypertension
# 9998  Pre-Diabetes
# 9999  Pre-Diabetes
#
# [10000 rows x 1 columns]

# %%
# Statistical Summary
df.describe()
# Out:
#                 Age           BMI  BloodPressure  GlucoseLevel   Cholesterol  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean      50.755300     26.082000     135.023800    175.252000    219.313500
# std       19.242137      4.461098      26.249406     60.536159     57.940956
# min       18.000000     16.000000      90.000000     70.000000    120.000000
# 25%       34.000000     23.000000     112.000000    123.000000    169.000000
# 50%       51.000000     26.000000     135.000000    174.000000    219.000000
# 75%       67.000000     29.100000     158.000000    227.000000    269.250000
# max       84.000000     44.700000     180.000000    280.000000    320.000000
#
#           HeartRate
# count  10000.000000
# mean      82.690100
# std       16.167628
# min       55.000000
# 25%       69.000000
# 50%       83.000000
# 75%       97.000000
# max      110.000000

# %%
# Check Missing Values
df.isnull().sum()
# Out:
# Age                 0
# Gender              0
# BMI                 0
# BloodPressure       0
# GlucoseLevel        0
# Cholesterol         0
# HeartRate           0
# Smoking             0
# Alcohol             0
# PhysicalActivity    0
# FamilyHistory       0
# Disease             0
# dtype: int64

# %%
# Data Types
df.dtypes
# Out:
# Age                   int64
# Gender                  str
# BMI                 float64
# BloodPressure         int64
# GlucoseLevel          int64
# Cholesterol           int64
# HeartRate             int64
# Smoking                 str
# Alcohol                 str
# PhysicalActivity        str
# FamilyHistory           str
# Disease                 str
# dtype: object

# %%
# Unique Disease Categories
df['Disease'].unique()
# Out:
# <StringArray>
# ['Healthy', 'Pre-Diabetes', 'Hypertension', 'Heart Disease', 'Diabetes']
# Length: 5, dtype: str

# %%
# Count of Each Disease
df['Disease'].value_counts()
# Out:
# Disease
# Healthy          6329
# Hypertension     1771
# Pre-Diabetes     1453
# Heart Disease     232
# Diabetes          215
# Name: count, dtype: int64

# %%
# Gender Distribution
df['Gender'].value_counts()
# Out:
# Gender
# Male      5011
# Female    4989
# Name: count, dtype: int64

# %%
# Disease Distribution Graph
sns.countplot(x='Disease', data=df)
plt.xticks(rotation=45)
plt.show()

# %%
# Gender Distribution Graph
sns.countplot(x='Gender', data=df)
plt.show()

# %%
# BMI Distribution
sns.histplot(df['BMI'], kde=True)
plt.show()

# %%
# Age Distribution
sns.histplot(df['Age'], kde=True)
plt.show()

# %%
# Correlation Matrix
numeric_df = df.select_dtypes(include=['int64','float64'])

plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True)
plt.show()

# %%
# Disease-wise Average BMI
df.groupby('Disease')['BMI'].mean()
# Out:
# Disease
# Diabetes         29.060930
# Healthy          25.463122
# Heart Disease    29.074569
# Hypertension     26.987634
# Pre-Diabetes     26.755265
# Name: BMI, dtype: float64

# %%
# Disease-wise Average Glucose Level
df.groupby('Disease')['GlucoseLevel'].mean()
# Out:
# Disease
# Diabetes         210.395349
# Healthy          164.537052
# Heart Disease    210.439655
# Hypertension     192.044608
# Pre-Diabetes     190.637990
# Name: GlucoseLevel, dtype: float64

# %%
# Disease-wise Average Cholesterol
df.groupby('Disease')['Cholesterol'].mean()
# Out:
# Disease
# Diabetes         258.627907
# Healthy          209.558382
# Heart Disease    257.810345
# Hypertension     236.284585
# Pre-Diabetes     229.155540
# Name: Cholesterol, dtype: float64
